# %%
import pandas as pd

# %%
stock_csv_path = "../../Analysis/Stock_data.csv"

stock_df = pd.read_csv(stock_csv_path)
stock_df
daily_change = abs(stock_df["Close"]-stock_df["Open"])
stock_df["Daily Change"] = daily_change
stock_df[['Month','Day','Year']] = stock_df['Date'].str.split('/',expand=True)
stock_df
# Out:
#            Date          Open          High           Low         Close  \
# 0      1/2/1992   3152.100098   3172.629883   3139.310059   3172.399902
# 1      1/3/1992   3172.399902   3210.639893   3165.919922   3201.500000
# 2      1/6/1992   3201.500000   3213.330078   3191.860107   3200.100098
# 3      1/7/1992   3200.100098   3210.199951   3184.479980   3204.800049
# 4      1/8/1992   3204.800049   3229.199951   3185.820068   3203.899902
# ...         ...           ...           ...           ...           ...
# 7322  1/27/2021  30893.779300  30893.779300  30206.910160  30303.169920
# 7323  1/28/2021  30377.189450  30951.410160  30377.189450  30603.359380
# 7324  1/29/2021  30553.910160  30553.910160  29856.300780  29982.619140
# 7325   2/1/2021  30054.730470  30335.910160  30014.970700  30211.910160
# 7326   2/2/2021  30276.880860  30840.539060  30276.880860  30687.480470
#
#          Adj Close   Volume  Daily Change Month Day  Year
# 0      3172.399902   235500     20.299804     1   2  1992
# 1      3201.500000   236200     29.100098     1   3  1992
# 2      3200.100098   272800      1.399902     1   6  1992
# 3      3204.800049   255100      4.699951     1   7  1992
# 4      3203.899902   290400      0.900147     1   8  1992
# ...            ...      ...           ...   ...  ..   ...
# 7322  30303.169920  5664700    590.609380     1  27  2021
# 7323  30603.359380  4651400    226.169930     1  28  2021
# 7324  29982.619140  5363200    571.291020     1  29  2021
# 7325  30211.910160  3470600    157.179690     2   1  2021
# 7326  30687.480470  3331600    410.599610     2   2  2021
#
# [7327 rows x 11 columns]

# %%
group_stock = stock_df.groupby(["Year"])

year_open = group_stock["Open"].first()
year_close = group_stock["Close"].last()
year_change = year_close-year_open
perc_change = ((year_close/year_open) - 1)*100
avg_close = group_stock["Close"].mean()
avg_change = group_stock["Daily Change"].mean()

# %%
dowjones_df = pd.DataFrame({
    "First Open": year_open,
    "Last Close": year_close,
    "Average Close": avg_close,
    "Year Change": year_change,
    "Percent Change": perc_change,
    "Avg Daily Change/Volatility": avg_change
    
})
dowjones_df["Percent Change"] = dowjones_df["Percent Change"].map("{:.2f}%".format)
dowjones_df["First Open"] = dowjones_df["First Open"].map("{:.2f}".format)
dowjones_df["Last Close"] = dowjones_df["Last Close"].map("{:.2f}".format)
dowjones_df["Average Close"] = dowjones_df["Average Close"]#.map("{:.2f}".format)
dowjones_df["Year Change"] = dowjones_df["Year Change"].map("{:.2f}".format)
dowjones_df["Avg Daily Change/Volatility"] = dowjones_df["Avg Daily Change/Volatility"].map("{:.2f}".format)
#dowjones_df.reset_index(level=0, inplace=True)
dowjones_df
# Out:
#      First Open Last Close  Average Close Year Change Percent Change  \
# Year
# 1992    3152.10    3301.11    3284.080357      149.01          4.73%
# 1993    3301.10    3754.09    3524.918453      452.99         13.72%
# 1994    3754.10    3834.44    3794.222298       80.34          2.14%
# 1995    3834.40    5117.12    4494.276383     1282.72         33.45%
# 1996    5115.70    6448.27    5739.626469     1332.57         26.05%
# 1997    6447.50    7908.30    7447.007625     1460.80         22.66%
# 1998    7910.20    9181.43    8630.764420     1271.23         16.07%
# 1999    9184.01   11497.12   10481.555222     2313.11         25.19%
# 2000   11501.85   10787.99   10729.377651     -713.86         -6.21%
# 2001   10790.92   10021.57   10208.861954     -769.35         -7.13%
# 2002   10021.71    8341.63    9214.852667    -1680.08        -16.76%
# 2003    8342.38   10453.92    9006.636667     2111.54         25.31%
# 2004   10452.74   10783.01   10315.512770      330.27          3.16%
# 2005   10783.75   10717.50   10546.655534      -66.25         -0.61%
# 2006   10718.30   12463.15   11409.779702     1744.85         16.28%
# 2007   12459.54   13264.82   13178.255381      805.28          6.46%
# 2008   13261.82    8776.39   11244.062604    -4485.43        -33.82%
# 2009    8772.25   10428.05    8885.654698     1655.80         18.88%
# 2010   10430.69   11577.51   10668.583458     1146.82         10.99%
# 2011   11577.43   12217.56   11957.570003      640.13          5.53%
# 2012   12221.19   13104.14   12965.313442      882.95          7.22%
# 2013   13104.30   16576.66   15009.522775     3472.36         26.50%
# 2014   16572.17   17823.07   16777.690937     1250.90          7.55%
# 2015   17823.07   17425.03   17587.088213     -398.04         -2.23%
# 2016   17405.48   19762.60   17927.107349     2357.12         13.54%
# 2017   19872.86   24719.22   21750.203748     4846.36         24.39%
# 2018   24809.35   23327.46   25053.949997    -1481.89         -5.97%
# 2019   23058.61   28538.44   26379.543798     5479.83         23.76%
# 2020   28638.97   30606.48   26890.673612     1967.51          6.87%
# 2021   30627.47   30687.48   30785.956660       60.01          0.20%
#
#      Avg Daily Change/Volatility
# Year
# 1992                       16.45
# 1993                       14.38
# 1994                       19.54
# 1995                       18.98
# 1996                       32.87
# 1997                       63.83
# 1998                       76.31
# 1999                       82.12
# 2000                      105.98
# 2001                       98.70
# 2002                      108.16
# 2003                       69.50
# 2004                       54.17
# 2005                       54.20
# 2006                       52.05
# 2007                       86.02
# 2008                      168.84
# 2009                       92.68
# 2010                       73.23
# 2011                      110.92
# 2012                       70.85
# 2013                       72.64
# 2014                       82.89
# 2015                      123.52
# 2016                       89.77
# 2017                       52.59
# 2018                      174.89
# 2019                      110.96
# 2020                      255.93
# 2021                      186.43

# %%
dowjones_df.to_csv("DowJones_Clean")

# %%
# Create a bar chart based off of the group series from before
#maker_group = used_car_df.groupby('maker')

# Count how many times each maker appears in our group
#count_makers = maker_group['maker'].count()

#count_makers

#dowjones_df = dowjones_df.groupby(["Year"]).count()
#dowjones_df
# Set the xlabel and ylabel using class methods
x = dowjones_df[["Average Close"]].plot(kind="bar")


#plt.show()
#plt.tight_layout()

# %%
# Class activity Create a bar chart based off of the group series from before
#count_chart = count_makers.plot(kind='bar')

# Set the xlabel and ylabel using class methods
#count_chart.set_xlabel("")
#count_chart.set_ylabel("Year")


plt.show()
plt.tight_layout()

# %%
#import matplotlib.pyplot as plt

dowjones_df.dtypes
# dowjones_df['Year Change'].isnull().sum()
ax = dowjones_df[['Avg Close/Volatility', 'Change years']].astype(float).plot(kind='bar', title =" ", figsize=(15, 10), legend=True, fontsize=12)
# ax.set_xlabel("Average Daily Change/Volatility", fontsize=12)
# ax.set_ylabel("", fontsize=12)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-520593d3768b> in <module>
#       3 dowjones_df.dtypes
#       4 # dowjones_df['Year Change'].isnull().sum()
# ----> 5 ax = dowjones_df[['Avg Close/Volatility', 'Change years']].astype(float).plot(kind='bar', title =" ", figsize=(15, 10), legend=True, fontsize=12)
#       6 # ax.set_xlabel("Average Daily Change/Volatility", fontsize=12)
#       7 # ax.set_ylabel("", fontsize=12)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Avg Close/Volatility', 'Change years'], dtype='object')] are in the [columns]"
