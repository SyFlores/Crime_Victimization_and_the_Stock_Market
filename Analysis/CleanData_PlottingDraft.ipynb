# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
file = '../Analysis/NCVS_dirty.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    year      weight  gender  race1r  hispanic  ethnic1r  ager  marital2  \
# 0  1993  2418.22376       1       1         2         1     2         1
# 1  1993  2258.95421       1       1         2         1     5         2
# 2  1993  2258.95421       1       1         2         1     5         2
# 3  1993  2258.95421       1       1         2         1     5         2
# 4  1993  2258.95421       1       1         2         1     5         2
#
#    hincome  popsize  ...  notify  weapon  weapcat  newcrime  newoff  \
# 0        5      NaN  ...       2       2        0         2       5
# 1        3      NaN  ...       1       2        0         1       4
# 2        3      NaN  ...       1       2        0         1       4
# 3        3      NaN  ...       1       2        0         1       4
# 4        3      NaN  ...       1       1        3         1       3
#
#    seriousviolent  injury  treatment  vicservices  locationr
# 0               3       0        0.0          2.0          4
# 1               2       1        1.0          2.0          3
# 2               2       1        1.0          2.0          3
# 3               2       1        1.0          2.0          3
# 4               1       1        1.0          2.0          3
#
# [5 rows x 23 columns]

# %%
df = df[df.year != 1993]
df = df[df.year != 1994]
df = df[df.year != 1995]

# %%
df.head()
# Out:
#        year      weight  gender  race1r  hispanic  ethnic1r  ager  marital2  \
# 12974  1996  3451.43740       1       1         2         1     5         2
# 12975  1996  2377.30718       2       1         2         1     6         2
# 12976  1996  2687.23144       1       1         2         1     5         2
# 12977  1996  2555.83758       2       1         2         1     5         2
# 12978  1996  3017.36110       1       1         2         1     5         1
#
#        hincome  popsize  ...  notify  weapon  weapcat  newcrime  newoff  \
# 12974        4      0.0  ...       1       2        0         1       4
# 12975        4      0.0  ...       2       2        0         1       4
# 12976        4      1.0  ...       1       3        5         1       4
# 12977        6      2.0  ...       2       2        0         1       4
# 12978        3      1.0  ...       2       2        0         1       4
#
#        seriousviolent  injury  treatment  vicservices  locationr
# 12974               2       0        0.0          2.0          5
# 12975               2       0        0.0          2.0          2
# 12976               2       0        0.0          2.0          3
# 12977               2       0        0.0          2.0          3
# 12978               2       0        0.0          2.0          3
#
# [5 rows x 23 columns]

# %%
#year_axis = np.arange(1993,
#year_axis

# %%
#array([ 1993,  1994,  1995,  1995,  5,  6,  7,  8,  9, 10, 11, 12])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cf19195cfc7c> in <module>
# ----> 1 array([ 1993,  1994,  1995,  1995,  5,  6,  7,  8,  9, 10, 11, 12])
#
# NameError: name 'array' is not defined

# %%
# Create a handle for each plot
#year, = plt.plot(year_axis, points_F, marker="+",color="blue", linewidth=1, label="Year")
#weapon, = plt.plot(weapon_axis, points_C, marker="s", color="Red", linewidth=1, label="Weapon")

# %%
# Set our legend to where the chart thinks is best
#plt.legend(handles=[year, weapon], loc="best")

# %%
# PiePLot Gender Based
#gender_df = pd.df(df.groupby(["Gender"]).count()).reset_index()
#gender_df.head()

# %%
#Alter the dataframe down to two columns
#gender_vic = df.groupby("gender")
#gender_group = gender_vic.count()
#gender_group

# %%
#labels = ["Male", "Female"]
#gender_count = gender_group["year"].tolist()
#gender_count

# %%
#plt.pie(gender_count, labels = labels)

# %%
gender_race = df.groupby("race1r")
gender_group1 = gender_race.count()
gender_group1
# Out:
#          year  weight  gender  hispanic  ethnic1r   ager  marital2  hincome  \
# race1r
# 1       38102   38102   38102     38102     38102  38102     38102    38102
# 2        6129    6129    6129      6129      6129   6129      6129     6129
# 3        2829    2829    2829      2829      2829   2829      2829     2829
#
#         popsize  region  ...  notify  weapon  weapcat  newcrime  newoff  \
# race1r                   ...
# 1         38102   38102  ...   38102   38102    38102     38102   38102
# 2          6129    6129  ...    6129    6129     6129      6129    6129
# 3          2829    2829  ...    2829    2829     2829      2829    2829
#
#         seriousviolent  injury  treatment  vicservices  locationr
# race1r
# 1                38102   38102      38073        37778      38102
# 2                 6129    6129       6120         6049       6129
# 3                 2829    2829       2825         2779       2829
#
# [3 rows x 22 columns]

# %%
labels = ["White", "Black", "Other"]
race_count1 = race_group1["year"].tolist()
race_count1
# Out:
# [38102, 6129, 2829]

# %%
plt.pie(gender_count1, labels = labels)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x1330a9ed3a0>,
#   <matplotlib.patches.Wedge at 0x1330a9ed850>,
#   <matplotlib.patches.Wedge at 0x1330a9edcd0>],
#  [Text(-0.9091029078151194, 0.6192995260793397, 'White'),
#   Text(0.7766742953699319, -0.7789589455880328, 'Black'),
#   Text(1.0804416104555032, -0.20650890149414527, 'Other')])

# %%
# Pie Chart "Reported/Not reported to the plocice/Not known"
# Needs to drop "3" - #Do not know
reported_group = df.groupby("notify")
reported_group = reported_group.count()
reported_group
# Out:
#          year  weight  gender  race1r  hispanic  ethnic1r   ager  marital2  \
# notify
# 1       21881   21881   21881   21881     21881     21881  21881     21881
# 2       24425   24425   24425   24425     24425     24425  24425     24425
# 3         622     622     622     622       622       622    622       622
# 8         132     132     132     132       132       132    132       132
#
#         hincome  popsize  ...  direl  weapon  weapcat  newcrime  newoff  \
# notify                    ...
# 1         21881    21881  ...  21881   21881    21881     21881   21881
# 2         24425    24425  ...  24425   24425    24425     24425   24425
# 3           622      622  ...    622     622      622       622     622
# 8           132      132  ...    132     132      132       132     132
#
#         seriousviolent  injury  treatment  vicservices  locationr
# notify
# 1                21881   21881      21854        21676      21881
# 2                24425   24425      24412        24335      24425
# 3                  622     622        620          591        622
# 8                  132     132        132            4        132
#
# [4 rows x 22 columns]

# %%
labels = ["1", "2", "3"]
reported_count = reported_group["year"].tolist()
reported_count
# Out:
# [21881, 24425, 622, 132]

# %%
plt.pie(gender_grouped, labels = labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-97425a8bf901> in <module>
# ----> 1 plt.pie(gender_grouped, labels = labels)
#
# NameError: name 'gender_grouped' is not defined

# %%
# Graph line "Income vs Year"

# %%
# Bar Charts
crime_outcomes = ["seriousviolent", "injury", "treatment"]
weight = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(weight))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, weight, color="b", align="center")
# Out:
# <BarContainer object of 5 artists>

# %%
tick_locations = [value for value in x_axis]
plt.xticks(tick_, crime_outcomes)
