# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
file = '../Analysis/NCVS_dirty.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    year      weight  gender  race1r  hispanic  ethnic1r  ager  marital2  \
# 0  1993  2418.22376       1       1         2         1     2         1
# 1  1993  2258.95421       1       1         2         1     5         2
# 2  1993  2258.95421       1       1         2         1     5         2
# 3  1993  2258.95421       1       1         2         1     5         2
# 4  1993  2258.95421       1       1         2         1     5         2
#
#    hincome  popsize  ...  notify  weapon  weapcat  newcrime  newoff  \
# 0        5      NaN  ...       2       2        0         2       5
# 1        3      NaN  ...       1       2        0         1       4
# 2        3      NaN  ...       1       2        0         1       4
# 3        3      NaN  ...       1       2        0         1       4
# 4        3      NaN  ...       1       1        3         1       3
#
#    seriousviolent  injury  treatment  vicservices  locationr
# 0               3       0        0.0          2.0          4
# 1               2       1        1.0          2.0          3
# 2               2       1        1.0          2.0          3
# 3               2       1        1.0          2.0          3
# 4               1       1        1.0          2.0          3
#
# [5 rows x 23 columns]

# %%
df = df[df.year != 1993]
df = df[df.year != 1994]
df = df[df.year != 1995]

# %%
df.head()
# Out:
#        year      weight  gender  race1r  hispanic  ethnic1r  ager  marital2  \
# 12974  1996  3451.43740       1       1         2         1     5         2
# 12975  1996  2377.30718       2       1         2         1     6         2
# 12976  1996  2687.23144       1       1         2         1     5         2
# 12977  1996  2555.83758       2       1         2         1     5         2
# 12978  1996  3017.36110       1       1         2         1     5         1
#
#        hincome  popsize  ...  notify  weapon  weapcat  newcrime  newoff  \
# 12974        4      0.0  ...       1       2        0         1       4
# 12975        4      0.0  ...       2       2        0         1       4
# 12976        4      1.0  ...       1       3        5         1       4
# 12977        6      2.0  ...       2       2        0         1       4
# 12978        3      1.0  ...       2       2        0         1       4
#
#        seriousviolent  injury  treatment  vicservices  locationr
# 12974               2       0        0.0          2.0          5
# 12975               2       0        0.0          2.0          2
# 12976               2       0        0.0          2.0          3
# 12977               2       0        0.0          2.0          3
# 12978               2       0        0.0          2.0          3
#
# [5 rows x 23 columns]

# %%
# Define dictionaries for replacing all of the variables
rep_ager = {1 : "12 to 14",
            2 : "15 to 17",
            3 : "18 to 20",
            4 : "21 to 24",
            5 : "25 to 34",
            6 : "35 to 49",
            7 : "50 to 64",
            8 : "65 or older"}

rep_newcrime = {1 : "Violent victimization",
                2 : "Personal theft/larceny"}

rep_hispanic = {1 : "Hispanic",
                2 : "Non-Hispanic"}

rep_hincome = {1 : "Less than $7,500",
               2 : "$7,500 to $14,999",
               3 : "$15,000 to $24,999",
               4 : "$25,000 to $34,999",
               5 : "$35,000 to $49,999",
               6 : "$50,000 to $74,999",
               7 : "$75,000 or more",
               88 : "Unknown"}

rep_injury = {0 : "Not Injured",
              1 : "Injured"}

rep_locationr = {1 : "At or near victim's home",
                 2 : "At or near friend, neighbor, or relative's home",
                 3 : "Commercial place, parking lot, or other public area",
                 4 : "School",
                 5 : "Other location"}

rep_msa = {1 : "Principal city within MSA",
           2 : "Not part of principal city within MSA",
           3 : "Outside MSA"}

rep_marital2 = {1 : "Never Married",
                2 : "Married",
                3 : "Widowed",
                4 : "Divorced",
                5 : "Separated"}

rep_treatment = {0 : "Not injured",
                 1 : "Not treated for injury",
                 2 : "Treated at scene, home, medical office, or other location"}

rep_popsize = {0 : "Not a place",
               1 : "Under 100,000",
               2 : "100,000 to 249,999",
               3 : "250,000 to 499,999",
               4 : "500,000 to 999,999",
               5 : "1 million or more"}

rep_weapon = {1 : "Yes, offender had weapon",
              2 : "No, offender did not have weapon",
              3 : "Do not know if offender had weapon"}

rep_race1r = {1 : "White",
              2 : "Black",
              3 : "Other"}

rep_ethnic1r = {1 : "Non-Hispanic white",
                2 : "Non-Hispanic black",
                3 : "Non-Hispanic other",
                4 : "Hispanic"}

rep_region = {1 : "Northeast",
              2 : "Midwest",
              3 : "South",
              4 : "West"}

rep_notify = {1 : "Yes, reported to the police",
              2 : "No, did not report to the police",
              3 : "Do not know"}

rep_gender = {1 : "Male",
              2 : "Female"}

rep_newoff = {1 : "Rape/sexual assault",
              2 : "Robbery",
              3 : "Aggravated assault",
              4 : "Simple assault",
              5 : "Personal theft"}

rep_vicservices = {1 : "Services received from victim service agencies",
                   2 : "No services received from victim service agencies"}

rep_direl = {1 : "Intimates",
             2 : "Other relatives",
             3 : "Well-known/casual acquaintances",
             4 : "Stranger",
             5 : "Do not know relationship",
             6 : "Do not know number of offenders"}

rep_seriousviolent = {1 : "Violent crime excluding simple assault",
                      2 : "Simple assault",
                      3 : "Personal theft",
                      4 : "Property crime"}

rep_weapcat = {0 : "No weapon",
               1 : "Firearm",
               2 : "Knife",
               3 : "Other type weapon",
               4 : "Type weapon unknown",
               5 : "Do not know if offender had weapon"}

# %%
df["ager"].replace(rep_ager ,inplace = True)
df["newcrime"].replace(rep_newcrime ,inplace = True)
df["hispanic"].replace(rep_hispanic ,inplace = True)
df["hincome"].replace(rep_hincome ,inplace = True)
df["injury"].replace(rep_injury ,inplace = True)
df["locationr"].replace(rep_locationr ,inplace = True)
df["msa"].replace(rep_msa ,inplace = True)
df["marital2"].replace(rep_marital2 ,inplace = True)
df["treatment"].replace(rep_treatment ,inplace = True)
df["popsize"].replace(rep_popsize ,inplace = True)
df["weapon"].replace(rep_weapon ,inplace = True)
df["race1r"].replace(rep_race1r ,inplace = True)
df["ethnic1r"].replace(rep_ethnic1r ,inplace = True)
df["region"].replace(rep_region ,inplace = True)
df["notify"].replace(rep_notify ,inplace = True)
df["gender"].replace(rep_gender ,inplace = True)
df["newoff"].replace(rep_newoff ,inplace = True)
df["vicservices"].replace(rep_vicservices ,inplace = True)
df["direl"].replace(rep_direl ,inplace = True)
df["seriousviolent"].replace(rep_seriousviolent ,inplace = True)
df["weapcat"].replace(rep_weapcat ,inplace = True)

# %%
df.head()
# Out:
#        year      weight  gender race1r      hispanic            ethnic1r  \
# 12974  1996  3451.43740    Male  White  Non-Hispanic  Non-Hispanic white
# 12975  1996  2377.30718  Female  White  Non-Hispanic  Non-Hispanic white
# 12976  1996  2687.23144    Male  White  Non-Hispanic  Non-Hispanic white
# 12977  1996  2555.83758  Female  White  Non-Hispanic  Non-Hispanic white
# 12978  1996  3017.36110    Male  White  Non-Hispanic  Non-Hispanic white
#
#            ager       marital2             hincome             popsize  ...  \
# 12974  25 to 34        Married  $25,000 to $34,999         Not a place  ...
# 12975  35 to 49        Married  $25,000 to $34,999         Not a place  ...
# 12976  25 to 34        Married  $25,000 to $34,999       Under 100,000  ...
# 12977  25 to 34        Married  $50,000 to $74,999  100,000 to 249,999  ...
# 12978  25 to 34  Never Married  $15,000 to $24,999       Under 100,000  ...
#
#                                  notify                              weapon  \
# 12974       Yes, reported to the police    No, offender did not have weapon
# 12975  No, did not report to the police    No, offender did not have weapon
# 12976       Yes, reported to the police  Do not know if offender had weapon
# 12977  No, did not report to the police    No, offender did not have weapon
# 12978  No, did not report to the police    No, offender did not have weapon
#
#                                   weapcat               newcrime  \
# 12974                           No weapon  Violent victimization
# 12975                           No weapon  Violent victimization
# 12976  Do not know if offender had weapon  Violent victimization
# 12977                           No weapon  Violent victimization
# 12978                           No weapon  Violent victimization
#
#                newoff  seriousviolent       injury    treatment  \
# 12974  Simple assault  Simple assault  Not Injured  Not injured
# 12975  Simple assault  Simple assault  Not Injured  Not injured
# 12976  Simple assault  Simple assault  Not Injured  Not injured
# 12977  Simple assault  Simple assault  Not Injured  Not injured
# 12978  Simple assault  Simple assault  Not Injured  Not injured
#
#                                              vicservices  \
# 12974  No services received from victim service agencies
# 12975  No services received from victim service agencies
# 12976  No services received from victim service agencies
# 12977  No services received from victim service agencies
# 12978  No services received from victim service agencies
#
#                                                locationr
# 12974                                     Other location
# 12975    At or near friend, neighbor, or relative's home
# 12976  Commercial place, parking lot, or other public...
# 12977  Commercial place, parking lot, or other public...
# 12978  Commercial place, parking lot, or other public...
#
# [5 rows x 23 columns]

# %%
#df.loc[df['notify'] == 8]

# %%
# Pie Chart "Victimization Male vs Female"
#df["gender"] = df.groupby(df["gender"]).count().reset_index()
df.count()


# The colors of each section of the pie chart
colors = ["red", "orange"]

# # Tells matplotlib to seperate the "Humans" section from the others
# explode = (0.1, 0, 0, 0)

labels = ["Male", "Female"]

plt.pie(list(df["gender"]), labels=labels, colors=colors,#autopct="%1.1f%%", shadow=True, startangle=140)

plt.show()
# Out:
#   File "<ipython-input-12-cc275b572f55>", line 16
#     plt.show()
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
gender_vic = df.groupby("gender")
gender_group = gender_vic.count()
gender_group

# %%
temp_df = df.groupby(df["gender"]).count().reset_index()
temp_df


# The colors of each section of the pie chart
colors = ["red", "orange"]

# # Tells matplotlib to seperate the "Humans" section from the others
# explode = (0.1, 0, 0, 0)

labels = ["Male", "Female"]

plt.pie(list(temp_df['gender']), labels=labels, colors = colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

plt.pie()

# %%
# Pie Chart "Victim-Offender Relationship"
v_o_relat_df =

# %%
# Pie Chart "Location vs Weight"

# %%
# Pie Chart "Weapon category"

# %%
# Pie Chart "Victim Services"

# %%
# Bar Chart "Location vs Years"
locations = ["At or near victim's home",  At or near friend, neighbor, or relative's home" "Commercial place, parking lot, or other public area","Other location]
years = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities, color="b", align="center")

# %%
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, cities)

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)

# %%
plt.title("Location vs Years")
plt.xlabel("Cities")
plt.ylabel("Location")

# %%
# Bar Chart "Weight vs Years"
# Can be useful in comparision with stock market data trends in certain years

# %%
# Bar Chart "Victimization Weight vs Age"

# %%
# Bar Chart "Victimization Weight vs Income"
