# %% [markdown]
# ### Define all packages and modules needed for the notebook.

# %%
import pandas as pd

# %% [markdown]
# ### Read in the primary raw Dow Jones Industrial dataset.

# %%
stock_csv_path = "../DataCleaning/DowJones_Dirty.csv"
stock_df = pd.read_csv(stock_csv_path)

# %% [markdown]
# ### Display sample of the raw Dow Jones Industrial dataset.
# - Notably, we see that we have daily information since 1992.

# %%
stock_df.shape
# Out:
# (7327, 7)

# %%
stock_df
# Out:
#            Date          Open          High           Low         Close  \
# 0      1/2/1992   3152.100098   3172.629883   3139.310059   3172.399902
# 1      1/3/1992   3172.399902   3210.639893   3165.919922   3201.500000
# 2      1/6/1992   3201.500000   3213.330078   3191.860107   3200.100098
# 3      1/7/1992   3200.100098   3210.199951   3184.479980   3204.800049
# 4      1/8/1992   3204.800049   3229.199951   3185.820068   3203.899902
# ...         ...           ...           ...           ...           ...
# 7322  1/27/2021  30893.779300  30893.779300  30206.910160  30303.169920
# 7323  1/28/2021  30377.189450  30951.410160  30377.189450  30603.359380
# 7324  1/29/2021  30553.910160  30553.910160  29856.300780  29982.619140
# 7325   2/1/2021  30054.730470  30335.910160  30014.970700  30211.910160
# 7326   2/2/2021  30276.880860  30840.539060  30276.880860  30687.480470
#
#          Adj Close   Volume
# 0      3172.399902   235500
# 1      3201.500000   236200
# 2      3200.100098   272800
# 3      3204.800049   255100
# 4      3203.899902   290400
# ...            ...      ...
# 7322  30303.169920  5664700
# 7323  30603.359380  4651400
# 7324  29982.619140  5363200
# 7325  30211.910160  3470600
# 7326  30687.480470  3331600
#
# [7327 rows x 7 columns]

# %% [markdown]
# ### Adding column for 'Daily Change'
# - We use the absolute value to account for changes regardless if decreasing or increasing.

# %%
stock_df["Daily Change"] = abs(stock_df["Close"]-stock_df["Open"])
stock_df.head()
# Out:
#        Date         Open         High          Low        Close    Adj Close  \
# 0  1/2/1992  3152.100098  3172.629883  3139.310059  3172.399902  3172.399902
# 1  1/3/1992  3172.399902  3210.639893  3165.919922  3201.500000  3201.500000
# 2  1/6/1992  3201.500000  3213.330078  3191.860107  3200.100098  3200.100098
# 3  1/7/1992  3200.100098  3210.199951  3184.479980  3204.800049  3204.800049
# 4  1/8/1992  3204.800049  3229.199951  3185.820068  3203.899902  3203.899902
#
#    Volume  Daily Change Month Day  Year
# 0  235500     20.299804     1   2  1992
# 1  236200     29.100098     1   3  1992
# 2  272800      1.399902     1   6  1992
# 3  255100      4.699951     1   7  1992
# 4  290400      0.900147     1   8  1992

# %% [markdown]
# ### Adding columns for 'Month', 'Day', and 'Year'
# - Splitting the 'Date' column to be able to more freely identify months, days and years.
# - Also allows us to have a joinable column against the NCVS dataset.

# %%
stock_df[['Month','Day','Year']] = stock_df['Date'].str.split('/',expand=True)
stock_df.head()
# Out:
#        Date         Open         High          Low        Close    Adj Close  \
# 0  1/2/1992  3152.100098  3172.629883  3139.310059  3172.399902  3172.399902
# 1  1/3/1992  3172.399902  3210.639893  3165.919922  3201.500000  3201.500000
# 2  1/6/1992  3201.500000  3213.330078  3191.860107  3200.100098  3200.100098
# 3  1/7/1992  3200.100098  3210.199951  3184.479980  3204.800049  3204.800049
# 4  1/8/1992  3204.800049  3229.199951  3185.820068  3203.899902  3203.899902
#
#    Volume  Daily Change Month Day  Year
# 0  235500     20.299804     1   2  1992
# 1  236200     29.100098     1   3  1992
# 2  272800      1.399902     1   6  1992
# 3  255100      4.699951     1   7  1992
# 4  290400      0.900147     1   8  1992

# %% [markdown]
# ### Create 'Year' groupby
# - We will use the functions to identify specific values for each year.
# - Specifically, we will identify yearly change, percent change, average close and average daily change.

# %%
group_stock = stock_df.groupby(["Year"])

year_open = group_stock["Open"].first()
year_close = group_stock["Close"].last()
year_change = year_close-year_open
perc_change = ((year_close/year_open) - 1)
avg_close = group_stock["Close"].mean()
avg_change = (group_stock["Daily Change"].mean()/avg_close)

# %% [markdown]
# ### Create a new dataframe using the 'Year' groupby's
# - Load in the variables (from the previous cell) as the dataframe columns.
# - We can only use those groupby variables as they're indexed on 'Year'.

# %%
dowjones_df = pd.DataFrame({
    "First Open": year_open,
    "Last Close": year_close,
    "Average Close": avg_close,
    "Year Change": year_change,
    "Percent Change": perc_change,
    "Avg Daily Change/Volatility": avg_change
})
dowjones_df.head()
# Out:
#        First Open   Last Close  Average Close  Year Change  Percent Change  \
# Year
# 1992  3152.100098  3301.110107    3284.080357   149.010009        0.047273
# 1993  3301.100098  3754.090088    3524.918453   452.989990        0.137224
# 1994  3754.100098  3834.439941    3794.222298    80.339843        0.021401
# 1995  3834.399902  5117.120117    4494.276383  1282.720215        0.334530
# 1996  5115.700195  6448.270020    5739.626469  1332.569825        0.260486
#
#       Avg Daily Change/Volatility
# Year
# 1992                     0.005008
# 1993                     0.004080
# 1994                     0.005150
# 1995                     0.004223
# 1996                     0.005727

# %% [markdown]
# ### Reformat the 'dowjones_df'
# - Adjust formatting for the aggregate variables.
# - Insert the 'Year' index as a column (will help with typical dataframe features).

# %%
dowjones_df["Percent Change"] = dowjones_df["Percent Change"].map("{:.5f}".format)
dowjones_df["First Open"] = dowjones_df["First Open"].map("{:.2f}".format)
dowjones_df["Last Close"] = dowjones_df["Last Close"].map("{:.2f}".format)
dowjones_df["Average Close"] = dowjones_df["Average Close"].map("{:.2f}".format)
dowjones_df["Year Change"] = dowjones_df["Year Change"].map("{:.2f}".format)
dowjones_df["Avg Daily Change/Volatility"] = dowjones_df["Avg Daily Change/Volatility"].map("{:.5f}".format)
dowjones_df.reset_index(level=0, inplace=True)
dowjones_df
# Out:
#     Year First Open Last Close Average Close Year Change Percent Change  \
# 0   1992    3152.10    3301.11       3284.08      149.01        0.04727
# 1   1993    3301.10    3754.09       3524.92      452.99        0.13722
# 2   1994    3754.10    3834.44       3794.22       80.34        0.02140
# 3   1995    3834.40    5117.12       4494.28     1282.72        0.33453
# 4   1996    5115.70    6448.27       5739.63     1332.57        0.26049
# 5   1997    6447.50    7908.30       7447.01     1460.80        0.22657
# 6   1998    7910.20    9181.43       8630.76     1271.23        0.16071
# 7   1999    9184.01   11497.12      10481.56     2313.11        0.25186
# 8   2000   11501.85   10787.99      10729.38     -713.86       -0.06206
# 9   2001   10790.92   10021.57      10208.86     -769.35       -0.07130
# 10  2002   10021.71    8341.63       9214.85    -1680.08       -0.16764
# 11  2003    8342.38   10453.92       9006.64     2111.54        0.25311
# 12  2004   10452.74   10783.01      10315.51      330.27        0.03160
# 13  2005   10783.75   10717.50      10546.66      -66.25       -0.00614
# 14  2006   10718.30   12463.15      11409.78     1744.85        0.16279
# 15  2007   12459.54   13264.82      13178.26      805.28        0.06463
# 16  2008   13261.82    8776.39      11244.06    -4485.43       -0.33822
# 17  2009    8772.25   10428.05       8885.65     1655.80        0.18875
# 18  2010   10430.69   11577.51      10668.58     1146.82        0.10995
# 19  2011   11577.43   12217.56      11957.57      640.13        0.05529
# 20  2012   12221.19   13104.14      12965.31      882.95        0.07225
# 21  2013   13104.30   16576.66      15009.52     3472.36        0.26498
# 22  2014   16572.17   17823.07      16777.69     1250.90        0.07548
# 23  2015   17823.07   17425.03      17587.09     -398.04       -0.02233
# 24  2016   17405.48   19762.60      17927.11     2357.12        0.13542
# 25  2017   19872.86   24719.22      21750.20     4846.36        0.24387
# 26  2018   24809.35   23327.46      25053.95    -1481.89       -0.05973
# 27  2019   23058.61   28538.44      26379.54     5479.83        0.23765
# 28  2020   28638.97   30606.48      26890.67     1967.51        0.06870
# 29  2021   30627.47   30687.48      30785.96       60.01        0.00196
#
#    Avg Daily Change/Volatility
# 0                      0.00501
# 1                      0.00408
# 2                      0.00515
# 3                      0.00422
# 4                      0.00573
# 5                      0.00857
# 6                      0.00884
# 7                      0.00783
# 8                      0.00988
# 9                      0.00967
# 10                     0.01174
# 11                     0.00772
# 12                     0.00525
# 13                     0.00514
# 14                     0.00456
# 15                     0.00653
# 16                     0.01502
# 17                     0.01043
# 18                     0.00686
# 19                     0.00928
# 20                     0.00546
# 21                     0.00484
# 22                     0.00494
# 23                     0.00702
# 24                     0.00501
# 25                     0.00242
# 26                     0.00698
# 27                     0.00421
# 28                     0.00952
# 29                     0.00606

# %% [markdown]
# ### Exporting the dataframe to be read into 'Analysis.ipynb'

# %%
dowjones_df.to_csv("DowJones_Clean")
